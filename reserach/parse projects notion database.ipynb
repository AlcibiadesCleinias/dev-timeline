# %%
from pydantic import BaseModel, TypeAdapter
from typing import List, Optional

class SeralizedProject(BaseModel):
    title: str
    subtitle: Optional[str]
    start: str
    description: str
    stack: List[str]
    additionalTags: Optional[List[str]]
    publicUrl: Optional[str]
    moreInfoUrl: Optional[str]
    awards: Optional[str]

SeralizedProjects = TypeAdapter(List[SeralizedProject])

# %%
import pandas as pd

# %%
df = pd.read_csv("Projects.csv")

# %%
df.head()
# Out:
#                                               Title  \
# 0                                Unstoppable Models
# 1  First atomic bridge-less cross-chain assets swap
# 2      Cloudless Computer Resources Market Explorer
# 3     Fluence Dao & Token Contract, DevDistribution
# 4             Smart Contract on Hardhat Boilerplate
#
#                                                Stack  \
# 0  Blockchain Indexer, Docker, Foundry, Python, S...
# 1                      ReactApp, Rust Smart Contract
# 2  Blockchain Indexer, Docker, Foundry, Github Ac...
# 3       Hardhat, Solidity Smart Contract, TypeScript
# 4   Github Actions, Hardhat, Solidity Smart Contract
#
#                                   Public Url  \
# 0  https://unstoppable-models.streamlit.app/
# 1            https://jamon-swap.why-nft.com/
# 2         https://explorer.kras.fluence.dev/
# 3            https://dao-fluence.vercel.app/
# 4                                        NaN
#
#                                                 Tags  \
# 0                          withDocs, 😀Research Code😀
# 1  Hackathon, MPC Protocol, withDocs, 😀Research C...
# 2     Industrial Project, with Admin Panel, withDocs
# 3                       Industrial Project, withDocs
# 4                                           Template
#
#                                          Source Code  \
# 0      https://github.com/sergmiller/eth-prague-2024
# 1  https://github.com/sergmiller/secured-jamon\n\...
# 2  https://github.com/fluencelabs/network-explore...
# 3                https://github.com/fluencelabs/dao/
# 4  https://github.com/AlcibiadesCleinias/hardhat-...
#
#                                          Description          Awards  \
# 0  [ETHPrague Hackathon] A public ML model traini...  🥇 on Hackathon
# 1  [ETHDam Hackathon] Presentation: https://githu...  🥉 on Hackathon
# 2  Web application to show the current market of ...             NaN
# 3  DAO & deploy docs: https://github.com/fluencel...             NaN
# 4  This repository contains a sample project that...             NaN
#
#          Start Date                                          notionUrl
# 0      June 2, 2024  https://www.notion.so/why-nft/Unstoppable-Mode...
# 1     April 1, 2024  https://www.notion.so/why-nft/First-atomic-bri...
# 2  January 31, 2024  https://www.notion.so/why-nft/Cloudless-Comput...
# 3  January 30, 2024  https://www.notion.so/why-nft/Fluence-Dao-Toke...
# 4   October 1, 2023  https://www.notion.so/why-nft/Smart-Contract-o...

# %%
import numpy as np
import json
from dateutil.parser import parse as parse_to_datetime
serialized: List[SeralizedProject] = []

unique_tags = set()
for index, row in df.iterrows():
    # print(f"{row.Tags}")
    stack = [x.strip() for x in row["Stack"].split(',')]
    unique_tags = unique_tags.union(stack)
    serialized.append(
        SeralizedProject(**{
            "title": row.Title,
        "subtitle": None,
        "start": f'{int(parse_to_datetime(row["Start Date"]).timestamp() * 1e3)}',
# .to_pydatetime()
            # Shorten description.
        "description": f'{row.Description}' if row.Description else "",
            # List all stacks.
        "stack": stack,
            # Create tags as "#tag".
        "additionalTags": ["".join(list(map(str.title, x.strip().split(" ")))) for x in row["Tags"].split(',')] if row["Tags"] is not np.nan else None,
            # Leave only 1 first url.
        "publicUrl": [x.strip() for x in row["Public Url"].split(',')][0] if row["Public Url"] is not np.nan else None,
        "moreInfoUrl": row["notionUrl"],
            "awards": row["Awards"] if row["Awards"] is not np.nan else None
        }
                        )
    )

json.dumps([x.dict() for x in serialized])
# Out:
# '[{"title": "Unstoppable Models", "subtitle": null, "start": "1717279200000", "description": "[ETHPrague Hackathon] A public ML model training initiative (as a public good) where anyone can freely submit the next weight update for the model on public dataset according to DAO controllable algorithm\\n\\nMore: https://devfolio.co/projects/unstoppable-models-94c1", "stack": ["Blockchain Indexer", "Docker", "Foundry", "Python", "Solidity Smart Contract"], "additionalTags": ["Withdocs", "\\ud83d\\ude00ResearchCode\\ud83d\\ude00"], "publicUrl": "https://unstoppable-models.streamlit.app/", "moreInfoUrl": "https://www.notion.so/why-nft/Unstoppable-Models-56d918c5110f4ba98c928ed27a055ea5", "awards": "\\ud83e\\udd47 on Hackathon"}, {"title": "First atomic bridge-less cross-chain assets swap", "subtitle": null, "start": "1711922400000", "description": "[ETHDam Hackathon] Presentation: https://github.com/sergmiller/secured-jamon/blob/main/0xSecuredJamon.pdf\\n\\nDemo: https://youtu.be/F6HxKk2WAm0", "stack": ["ReactApp", "Rust Smart Contract"], "additionalTags": ["Hackathon", "MpcProtocol", "Withdocs", "\\ud83d\\ude00ResearchCode\\ud83d\\ude00"], "publicUrl": "https://jamon-swap.why-nft.com/", "moreInfoUrl": "https://www.notion.so/why-nft/First-atomic-bridge-less-cross-chain-assets-swap-8fd4cd54a2594276a3f0c0943dda6cb6", "awards": "\\ud83e\\udd49 on Hackathon"}, {"title": "Cloudless Computer Resources Market Explorer", "subtitle": null, "start": "1706655600000", "description": "Web application to show the current market of Offers, Provider, Deals, CC.\\nThe main client of the application is a Provider.", "stack": ["Blockchain Indexer", "Docker", "Foundry", "Github Actions", "ReactApp", "Solidity Smart Contract", "TypeScript"], "additionalTags": ["IndustrialProject", "WithAdminPanel", "Withdocs"], "publicUrl": "https://explorer.kras.fluence.dev/", "moreInfoUrl": "https://www.notion.so/why-nft/Cloudless-Computer-Resources-Market-Explorer-df59e25b60ee44929ad1ca7a973b7919", "awards": null}, {"title": "Fluence Dao & Token Contract, DevDistribution", "subtitle": null, "start": "1706569200000", "description": "DAO & deploy docs: https://github.com/fluencelabs/dao/tree/main/contracts#dao-proposal-flow", "stack": ["Hardhat", "Solidity Smart Contract", "TypeScript"], "additionalTags": ["IndustrialProject", "Withdocs"], "publicUrl": "https://dao-fluence.vercel.app/", "moreInfoUrl": "https://www.notion.so/why-nft/Fluence-Dao-Token-Contract-DevDistribution-21c999156053405f9867f211030148af", "awards": null}, {"title": "Smart Contract on Hardhat Boilerplate", "subtitle": null, "start": "1696111200000", "description": "This repository contains a sample project that you can use as the starting point for your Ethereum project", "stack": ["Github Actions", "Hardhat", "Solidity Smart Contract"], "additionalTags": ["Template"], "publicUrl": null, "moreInfoUrl": "https://www.notion.so/why-nft/Smart-Contract-on-Hardhat-Boilerplate-bae985c9f1594821a748d5239894bc6c", "awards": null}, {"title": "11 AI - Help Based on Internal Data", "subtitle": null, "start": "1696111200000", "description": "[Junction Hackathon] AI with LLM as\\nservice to aid managers in handling complicated technical and economic\\nissues through a chat. Processing real-time awareness, sustainability,\\nscalability, and seamless integration with a wide array of data sources (ref to Junction Hackathon). Presentation: https://github.com/sergmiller/junction2023/blob/master/docs/11AIJunction2023_Final.pptx", "stack": ["Django", "Docker", "ML", "ReactApp"], "additionalTags": ["Ai", "Hackathon", "Llm", "Withdocs", "\\ud83d\\ude00ResearchCode\\ud83d\\ude00"], "publicUrl": null, "moreInfoUrl": "https://www.notion.so/why-nft/11-AI-Help-Based-on-Internal-Data-641e74fcea004ff4bad6f736d60bc5a0", "awards": null}, {"title": "test: https://github.com/AlcibiadesCleinias/binary-search-tree-solidity-library", "subtitle": null, "start": "1690840800000", "description": "In order to demonstrate a solidity library rea ...

# %%
(unique_tags)
# Out:
# {'Bitbucket Pipelines',
#  'Blockchain Indexer',
#  'C',
#  'Celery',
#  'DataDog',
#  'Django',
#  'Docker',
#  'FastAPI',
#  'Flask',
#  'Fluence Oracles',
#  'Foundry',
#  'Github Actions',
#  'Gitlab CI&CD',
#  'Grafana',
#  'Hardhat',
#  'JavaScript',
#  'K8s',
#  'ML',
#  'Nginx',
#  'Node.js',
#  'PostgreSQL',
#  'Prometheus',
#  'Python',
#  'RabbitMQ',
#  'ReactApp',
#  'Redis',
#  'Rust Smart Contract',
#  'Solidity Smart Contract',
#  'TelegramBot',
#  'Truffle',
#  'TypeScript',
#  'iOS App'}
